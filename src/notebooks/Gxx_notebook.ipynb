# %% [markdown]
# <H3>DASH: Análise Não Supervisionada</H3>

# %% [markdown]
# **GROUP XX**
# - name, number, e-mail
# - name, number, e-mail

# %% [markdown]
# *Note*: the provided structure is merely suggestive.

# %% [markdown]
# <H3>Part I: data profiling and representation</H3>

# %% [markdown]
# **Descriptive statistics**

# %%
#code, statistics and charts here

# %% [markdown]
# **Data representations**

# %%
#code, statistics and charts here

# %% [markdown]
# **Explainable predictive models** (optional)

# %%
#code, statistics and charts here

# %% [markdown]
# **Applied transformations**

# %%
#code, statistics and charts here

# %% [markdown]
# <H3>Part II: clustering analysis</H3>

# %% [markdown]
# **Reference clustering solution**

# %%
#code, statistics and charts here

# %% [markdown]
# **Visualization and cluster labeling**

# %%
#code, statistics and charts here

# %% [markdown]
# **Impact of distance functions and methods**

# %%
#code, statistics and charts here

# %% [markdown]
# **Number of clusters**

# %%
#code, statistics and charts here

# %% [markdown]
# **Impact of preprocessing options**

# %%
#code, statistics and charts here

# %% [markdown]
# **Detailed assessment**

# %%
#code, statistics and charts here

# %% [markdown]
# <H3>Part III: outlier or pattern analysis</H3>

# %% [markdown]
# **Reference outlier/pattern solutions**

# %%
#code, statistics and charts here

# %% [markdown]
# **Preprocessing impact**

# %%
#code, statistics and charts here

# %% [markdown]
# **Class-conditional outliers/patterns** (optional)

# %%
#code, statistics and charts here

# %% [markdown]
# **Detailed assessment**

# %%
#code, statistics and charts here

# %% [markdown]
# <H3>END</H3>
